# %% [markdown]
# # Lecture 2: Distributions and Frequencies

# %% [markdown]
# ### Objectives
# - Learn to plot univariate distributions
# - Understand when to use histograms, KDE plots, rug plots, and ECDFs
# - Experiment with bin sizes and axis transformations
# - Choose the right plot based on variable type

# %% [markdown]
# ## Histograms and Kernel Density Plots

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="darkgrid")
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
frame = pd.read_csv('../Data/frmgham2.csv')
frame.head()
# Out:
#    RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 0    2448    1    195.0   39  106.0   70.0         0      0.0  26.97
# 1    2448    1    209.0   52  121.0   66.0         0      0.0    NaN
# 2    6238    2    250.0   46  121.0   81.0         0      0.0  28.73
# 3    6238    2    260.0   52  105.0   69.5         0      0.0  29.43
# 4    6238    2    237.0   58  108.0   66.0         0      0.0  28.50
#
#    DIABETES  ...  CVD  HYPERTEN  TIMEAP  TIMEMI  TIMEMIFC  TIMECHD  TIMESTRK  \
# 0         0  ...    1         0    8766    6438      6438     6438      8766
# 1         0  ...    1         0    8766    6438      6438     6438      8766
# 2         0  ...    0         0    8766    8766      8766     8766      8766
# 3         0  ...    0         0    8766    8766      8766     8766      8766
# 4         0  ...    0         0    8766    8766      8766     8766      8766
#
#    TIMECVD  TIMEDTH  TIMEHYP
# 0     6438     8766     8766
# ...

# %% [markdown]
# # Research question 1: what is the distribution of age in this dataset?

# %% [markdown]
# * We are dealing with a single variable
# * We want to count elements of that variable within bins
# * => use histogram

# %%
# Matplotlib version
plt.hist(frame['AGE'], bins = 10)
plt.xlabel('value')
plt.ylabel('count');

# %%
# Seaborn version -- try this yourself!
sns.histplot(data = frame, x = 'AGE')
# Out:
# <Axes: xlabel='AGE', ylabel='Count'>

# %% [markdown]
# # Plotting smooth distribution shape: kernel density plot

# %%
# KDE Plot
sns.kdeplot(data=frame, x="AGE", fill=True)
plt.title("KDE Plot of Age")
plt.show()

# %% [markdown]
# # Using log scales for skewed data

# %%
# Matplotlib version
plt.hist(frame['TOTCHOL'], bins = 30)
plt.xlabel('value')
plt.ylabel('count');
plt.xscale('log')

# %%
# Seaborn version
# KDE Plot
sns.kdeplot(data=frame, x="TOTCHOL", fill=True)
plt.xscale('log')
plt.title("KDE Plot of Total Cholesterol")
plt.show()

# %% [markdown]
# ## Rug Plots and ECDFs

# %%
# Powerful use of Seaborn: stacking plots
sns.kdeplot(data=frame, x="TOTCHOL", fill=True)
sns.rugplot(data=frame, x="TOTCHOL")
plt.title("KDE with Rug Plot")
plt.show()

# %%
# ECDF Plot
sns.ecdfplot(data=frame, x="AGE")
plt.title("ECDF of AGE in Framingham Heart Study")
plt.show()

# %% [markdown]
# ## 🛠 Practice: Visualize Systolic Blood Pressure Distributions
# 1. Create a histogram of systolic blood pressure (SYSBP).
# 2. Create a KDE of SYSBP.
# 3. Apply a log scale transformation to the x-axis.
# 4. Compare the raw and log-scaled versions.
