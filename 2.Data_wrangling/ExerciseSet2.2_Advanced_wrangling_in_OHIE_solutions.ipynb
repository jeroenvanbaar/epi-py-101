# %% [markdown]
# # Homework: Data Wrangling with the Oregon Health Insurance Experiment (OHIE)
# This exercise set is based on the `OHIE_12m.csv` dataset and is designed to take about 45 minutes.
#
# In this exercise, you will:
# - Recode and rename variables
# - Create derived variables using `.apply()` and `lambda`
# - Query the data using `.query()`
# - Aggregate data using `.groupby()` and `.agg()`
#
# Let's begin by importing pandas and loading the dataset:

# %%
import pandas as pd

# Make Google Drive available to the script
from google.colab import drive
drive.mount('/content/drive')

# Let's load the Oregon Health Insurance Experiment dataset
filename = 'drive/MyDrive/Colab Notebooks/Intro to Python for Epidemiologists/Data/OHIE_12m.csv'
OHIE = pd.read_csv(filename)
OHIE.head()
# Out:
# Mounted at /content/drive
#    person_id  household_id     treatment  \
# 0      64350        164350  Not selected
# 1      55655        155655  Not selected
# 2      20087        128134      Selected
# 3      70998        170998  Not selected
# 4       8839        108839      Selected
#
#                                draw_treat    draw_lottery  \
# 0                                     NaN  Lottery Draw 6
# 1                                     NaN  Lottery Draw 7
# 2  Draw 6: selected in lottery 07/01/2008  Lottery Draw 6
# 3                                     NaN  Lottery Draw 7
# 4  Draw 8: selected in lottery 09/02/2008  Lottery Draw 8
#
#                             applied_app approved_app dt_notify_lottery  \
# 0                                   NaN          NaN        2008-07-14
# 1                                   NaN          NaN        2008-08-12
# 2       Submitted an Application to OHP           No        2008-07-14
# 3                                   NaN          NaN        2008-08-12
# 4  Did NOT submit an application to OHP           No        2008-09-11
#
#   dt_retro_coverage  birthyear_list  ... live_partner_12m live_parents_12m  \
# 0        2008-08-08            1974  ...               No              Yes
# 1        2008-09-08            1987  ...              Yes               No
# 2        2008-08-08            1963  ...               No               No
# 3        2008-09-08            1954  ...              Yes               No
# 4        2008-10-08            1964  ...               No               No
#
#    live_friends_12m live_relatives_12m live_other_12m hhsize_12m PHQ2_1  \
# 0                No                 No             No        2.0    3.0
# 1                No                 No             No        2.0    1.0
# 2                No                Yes             No        7.0    0.0
# 3                No                 No             No        2.0    3.0
# 4               Yes                 No             No        4.0    2.0
#
#   PHQ2_2 PHQ2_sum PHQ2_cutoff
# 0    3.0      6.0        True
# 1    1.0      2.0       False
# 2    1.0      1.0       False
# 3    2.0      5.0        True
# 4    2.0      4.0        True
#
# [5 rows x 44 columns]

# %% [markdown]
# # Start by orienting yourself on the dataset
# Use .head, .shape, .info

# %%
OHIE.shape
# Out:
# (4000, 44)

# %%
OHIE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 44 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   person_id            4000 non-null   int64
#  1   household_id         4000 non-null   int64
#  2   treatment            4000 non-null   object
#  3   draw_treat           2011 non-null   object
#  4   draw_lottery         4000 non-null   object
#  5   applied_app          2010 non-null   object
#  6   approved_app         2010 non-null   object
#  7   dt_notify_lottery    4000 non-null   object
#  8   dt_retro_coverage    4000 non-null   object
#  9   birthyear_list       4000 non-null   int64
#  10  female_list          4000 non-null   object
#  11  ins_any_12m          3939 non-null   object
#  12  weight_12m           4000 non-null   float64
#  13  employ_12m           3868 non-null   object
#  14  edu_12m              3853 non-null   object
#  15  dep_sad_12m          3936 non-null   object
#  16  dep_interest_12m     3927 non-null   object
#  17  dep_rx_12m           3595 non-null   object
#  18  smk_curr_12m         3884 non-null   object
#  19  smk_ever_12m         3929 non-null   object
#  20  race_white_12m       4000 non-null   object
#  21  race_black_12m       4000 non-null   object
#  22  race_hisp_12m        3957 non-null   object
#  23  race_asian_12m       4000 non-null   object
#  24  race_amerindian_12m  4000 non-null   object
#  25  race_pacific_12m     4000 non-null   object
#  26  race_other_qn_12m    4000 non-null   object
#  27  chl_chk_12m          3936 non-null   object
#  28  dia_chk_12m          3935 non-null   object
#  29  mam_chk_12m          2391 non-null   object
#  30  pap_chk_12m          2391 non-null   object
#  31  hhinc_cat_12m        3790 non-null   object
#  32  hhinc_pctfpl_12m     3598 non-null   float64
#  33  live_alone_12m       3999 non-null   object
#  34  live_partner_12m     3999 non-null   object
#  35  live_parents_12m     4000 non-null   object
#  36  live_friends_12m     4000 non-null   object
#  37  live_relatives_12m   4000 non-null   object
#  38  live_other_12m       4000 non-null   object
#  39  hhsize_12m           3780 non-null   float64
#  40  PHQ2_1               3936 non-null   float64
#  41  PHQ2_2               3927 non-null   float64
#  42  PHQ2_sum             3895 non-null   float64
#  43  PHQ2_cutoff          3895 non-null   object
# dtypes: float64(6), int64(3), object(35)
# memory usage: 1.3+ MB

# %% [markdown]
# ## Exercise 1: Renaming Columns
# Rename the following columns to more readable names:
#
# - `PHQ2_sum` → `depression_score`
# - `PHQ2_cutoff` → `depressed`
# - `smk_curr_12m` → `current_smoker`
# - `edu_12m` → `education`
#
# Store the renamed DataFrame as `df_renamed`.

# %%
# Your code here
df_renamed = OHIE.rename(columns = {'PHQ2_sum':'depression_score',
                                    'PHQ2_cutoff':'depressed',
                                    'smk_curr_12m':'current_smoker',
                                    'edu_12m':'education'})
df_renamed.columns
# Out:
# Index(['person_id', 'household_id', 'treatment', 'draw_treat', 'draw_lottery',
#        'applied_app', 'approved_app', 'dt_notify_lottery', 'dt_retro_coverage',
#        'birthyear_list', 'female_list', 'ins_any_12m', 'weight_12m',
#        'employ_12m', 'education', 'dep_sad_12m', 'dep_interest_12m',
#        'dep_rx_12m', 'current_smoker', 'smk_ever_12m', 'race_white_12m',
#        'race_black_12m', 'race_hisp_12m', 'race_asian_12m',
#        'race_amerindian_12m', 'race_pacific_12m', 'race_other_qn_12m',
#        'chl_chk_12m', 'dia_chk_12m', 'mam_chk_12m', 'pap_chk_12m',
#        'hhinc_cat_12m', 'hhinc_pctfpl_12m', 'live_alone_12m',
#        'live_partner_12m', 'live_parents_12m', 'live_friends_12m',
#        'live_relatives_12m', 'live_other_12m', 'hhsize_12m', 'PHQ2_1',
#        'PHQ2_2', 'depression_score', 'depressed'],
#       dtype='object')

# %% [markdown]
# ## Exercise 2: Recoding Categorical Variables
# Let's inspect the `current_smoker` variable. What are the levels? How many participants fall into each level? Recode such that participants who smoke even a little bit get a 1, and only participants who smoke not at all get a 0. Store the result in a new column called `smoker_binary`.

# %%
df_renamed['current_smoker'].value_counts()
# Out:
# current_smoker
# not at all    2291
# every day     1255
# some days      338
# Name: count, dtype: int64

# %%
# Your code here
df_renamed['smoker_binary'] = (df_renamed['current_smoker']
                               .replace({'every day':1,'some days':1,'not at all':0})
                               .astype('Int64'))
df_renamed[['current_smoker','smoker_binary']].head()
# Out:
# <ipython-input-9-59234e304be9>:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .replace({'every day':1,'some days':1,'not at all':0})
#   current_smoker  smoker_binary
# 0     not at all              0
# 1     not at all              0
# 2     not at all              0
# 3     not at all              0
# 4      some days              1

# %% [markdown]
# ## Exercise 3: Creating a Derived Variable with `apply()`
# Use the `birthyear_list` column to calculate age (assuming the year is 2008) and store it as a new column `age`.

# %%
# Your code here
df_renamed['age'] = df_renamed['birthyear_list'].apply(lambda x: 2008 - x)
df_renamed[['birthyear_list','age']].head()
# Out:
#    birthyear_list  age
# 0            1974   34
# 1            1987   21
# 2            1963   45
# 3            1954   54
# 4            1964   44

# %% [markdown]
# ## Exercise 4: Create a Depression Severity Category
# Using `depression_score`, create a new column `depression_category` with the following logic:
#
# - 0–2: 'None'
# - 3–4: 'Mild'
# - 5–6: 'Moderate'
# - 7–8: 'Severe'
#
# Use `.apply()` with a custom function or a `lambda`. Store the result in an ordered categorical variable.

# %%
# Your code here
depr_levels = ['None', 'Mild','Moderate','Severe']
df_renamed['depression_category'] = pd.cut(df_renamed['depression_score'],
                                bins = [0, 3, 5, 7, 9],
                                labels = depr_levels)
df_renamed['depression_category'] = pd.Categorical(
    df_renamed['depression_category'],
    categories = depr_levels,
    ordered = True
)
df_renamed[['depression_score','depression_category']].head()
# Out:
#    depression_score depression_category
# 0               6.0            Moderate
# 1               2.0                None
# 2               1.0                None
# 3               5.0                Mild
# 4               4.0                Mild

# %%
# Checking the ordering
df_renamed['depression_category'].dtype
# Out:
# CategoricalDtype(categories=['None', 'Mild', 'Moderate', 'Severe'], ordered=True, categories_dtype=object)

# %% [markdown]
# ## Exercise 5: Querying the Data
# Using `.query()`, filter the dataset to include only respondents who are:
#
# - Female (`female_list == "1: Female"`) (mind the double quotes)
# - Currently smoke (using the new `smoker_binary` variable)
# - Have a `depression_score` of 5 or more
#
# Store this subset as `df_query`.

# %%
# Your code here
df_query = df_renamed.query('female_list == "1: Female" and smoker_binary == 1 and depression_score >= 5')
df_query
# Out:
# <ipython-input-22-609138c542a4>:2: RuntimeWarning: Engine has switched to 'python' because numexpr does not support extension array dtypes. Please set your engine to python manually.
#   df_query = df_renamed.query('female_list == "1: Female" and smoker_binary == 1 and depression_score >= 5')
#       person_id  household_id     treatment  \
# 22        28584        128584  Not selected
# 36        21051        121051      Selected
# 72        64335        164335      Selected
# 80        35463        135463  Not selected
# 89         1488        101488      Selected
# ...         ...           ...           ...
# 3863      13053        113053      Selected
# 3881      16361        150982      Selected
# 3906      35172        154209  Not selected
# 3915      46867        146867      Selected
# 3967      38640        174813      Selected
#
#                                   draw_treat    draw_lottery  \
# 22                                       NaN  Lottery Draw 3
# 36    Draw 4: selected in lottery 05/01/2008  Lottery Draw 4
# 72    Draw 1: selected in lottery 03/05/2008  Lottery Draw 1
# 80                                       NaN  Lottery Draw 8
# 89    Draw 2: selected in lottery 03/27/2008  Lottery Draw 2
# ...                                      ...             ...
# 3863  Draw 8: selected in lottery 09/02/2008  Lottery Draw 8
# 3881  Draw 8: selected in lottery 09/02/2008  Lottery Draw 8
# 3906                                     NaN  Lottery Draw 2
# 3915  Draw 5: selected in lottery 06/02/2008  Lottery Draw 5
# 3967  Draw 5: selected in lottery 06/02/2008  Lottery Draw 5
#
#                                applied_app approved_app dt_notify_lottery  \
# 22                                     NaN          NaN        2008-04-16
# 36         Submitted an Application to OHP           No        2008-05-09
# 72         Submitted an Application to OHP          Yes        2008-03-10
# 80                                     NaN          NaN        2008-09-11
# 89    Did NOT submit an application to OHP           No        2008-04-07
# ...                                    ...          ...               ...
# 3863       Submitted an Application to OHP          Yes        2008-09-11
# 3881       Submitted an Application to OHP           No        2008-09-11
# 3906                                   NaN          NaN        2008-04-07
# 3915       Submitted an Application to OHP           No        2008-06-11
# 3967       Submitted an Application to OHP           No        2008-06-11
#
#      dt_retro_coverage  birthyear_list  ... live_other_12m hhsize_12m  PHQ2_1  \
# 22          2008-05-08            1960  ...             No        2.0     3.0
# 36          2008-06-09            1955  ...             No        2.0     3.0
# 72          2008-03-11            1961  ...             No        2.0     3.0
# 80          2008-10-08            1968  ...             No        2.0     3.0
# 89          2008-04-08            1971  ...             No        1.0     3.0
# ...                ...             ...  ...            ...        ...     ...
# 3863        2008-10-08            1972  ...             No        3.0     2.0
# 3881        2008-10-08            1981  ...            Yes        5.0     3.0
# 3906        2008-04-08            1956  ...             No        2.0     3.0
# 3915        2008-07-08            1967  ...             No        3.0     3.0
# 3967        2008-07-08            1959  ...             No        2.0     3.0
#
#      PHQ2_2 depression_score depressed smoker_binary age  depr_cat  \
# 22      3.0              6.0      True             1  48  Moderate
# 36      3.0              6.0      True             1  53  Moderate
# 72      3.0              6.0      True             1  47  Moderate
# 80      3.0              6.0      True             1  40  Moderate
# 89      3.0              6.0      True             1  37  Moderate
# ...     ...              ...       ...           ...  ..       ...
# 3863    3.0              5.0      True             1  36      Mild
# 3881    3.0              6.0      True             1  27  Moderate
# 3906    3.0              6.0      True             1  52  Moderate
# 3915    3.0              6.0      True             1  41  Moderate
# 3967    3.0              6.0      True             1  49  Moderate
#
#      depression_category
# 22              Moderate
# 36              Moderate
# 72              Moderate
# 80              Moderate
# 89              Moderate
# ...                  ...
# 3863                Mild
# 3881            Moderate
# 3906            Moderate
# 3915            Moderate
# 3967            Moderate
#
# [192 rows x 48 columns]

# %% [markdown]
# ## Exercise 6: Aggregating the Data
# Using `.groupby()` and `.agg()`, compute the mean `depression_score` and mean `age` grouped by `treatment` group.

# %%
# Your code here
df_renamed.groupby('treatment').agg({'depression_score':'mean',
                                     'age':'mean'})
# Out:
#               depression_score        age
# treatment
# Not selected          2.205325  42.550025
# Selected              1.933574  42.296370
