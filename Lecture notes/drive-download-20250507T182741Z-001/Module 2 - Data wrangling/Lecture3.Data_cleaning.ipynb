# %% [markdown]
# # Learning objectives
# By the end of this lecture, you will know:
# - How to identify missing data in a DataFrame
# - How to inspect, filter, drop, or fill missing data
# - Learn how to inspect and fix data types in a DataFrame
# - How to save your cleaned DataFrame to a CSV file.

# %% [markdown]
# # Functions vs. Methods

# %%
# We have seen functions:
mylist = [2,3,4]
len(mylist)
# Out:
# 3

# %%
# We have also seen methods:
import pandas as pd
mydf = pd.DataFrame({'A':mylist})
print(mydf)
mydf.mean()
# Out:
#    A
# 0  2
# 1  3
# 2  4
# A    3.0
# dtype: float64

# %% [markdown]
# # Checking for missing data

# %%
# In Python, missing data are represented as NaN (not a number)
import numpy as np
np.nan
# Out:
# nan

# %%
# Example dataset
patients = pd.DataFrame({
    'id': [1,2,3,4],
    'age': [34, np.nan, 45, 29],
    'smoker': ['yes',np.nan,np.nan,'no'],
    'bmi': [25.3, 27.8, np.nan, 24.5]
})
print(patients)
# Out:
#    id   age smoker   bmi
# 0   1  34.0    yes  25.3
# 1   2   NaN    NaN  27.8
# 2   3  45.0    NaN   NaN
# 3   4  29.0     no  24.5

# %%
print(patients.isna())
# Out:
#       id    age  smoker    bmi
# 0  False  False   False  False
# 1  False   True   False  False
# 2  False  False    True   True
# 3  False  False   False  False

# %%
print(patients.isna().sum())
# Out:
# id        0
# age       1
# smoker    2
# bmi       1
# dtype: int64

# %% [markdown]
# ## Applying this to Framingham dataset

# %%
# Make Google Drive available to the script
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Let's load the Framingham Heart Study dataset
filename = 'drive/MyDrive/Colab Notebooks/Intro to Python for Epidemiologists/Data/frmgham2.csv'
frame = pd.read_csv(filename)
frame.head()
# Out:
#    RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 0    2448    1    195.0   39  106.0   70.0         0      0.0  26.97
# 1    2448    1    209.0   52  121.0   66.0         0      0.0    NaN
# 2    6238    2    250.0   46  121.0   81.0         0      0.0  28.73
# 3    6238    2    260.0   52  105.0   69.5         0      0.0  29.43
# 4    6238    2    237.0   58  108.0   66.0         0      0.0  28.50
#
#    DIABETES  ...  CVD  HYPERTEN  TIMEAP  TIMEMI  TIMEMIFC  TIMECHD  TIMESTRK  \
# 0         0  ...    1         0    8766    6438      6438     6438      8766
# 1         0  ...    1         0    8766    6438      6438     6438      8766
# 2         0  ...    0         0    8766    8766      8766     8766      8766
# 3         0  ...    0         0    8766    8766      8766     8766      8766
# 4         0  ...    0         0    8766    8766      8766     8766      8766
#
#    TIMECVD  TIMEDTH  TIMEHYP
# 0     6438     8766     8766
# 1     6438     8766     8766
# 2     8766     8766     8766
# 3     8766     8766     8766
# 4     8766     8766     8766
#
# [5 rows x 39 columns]

# %%
# Checking for missing values
print(frame.isna())
# Out:
#        RANDID    SEX  TOTCHOL    AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 0       False  False    False  False  False  False     False    False  False
# 1       False  False    False  False  False  False     False    False   True
# 2       False  False    False  False  False  False     False    False  False
# 3       False  False    False  False  False  False     False    False  False
# 4       False  False    False  False  False  False     False    False  False
# ...       ...    ...      ...    ...    ...    ...       ...      ...    ...
# 11622   False  False    False  False  False  False     False    False  False
# 11623   False  False    False  False  False  False     False    False  False
# 11624   False  False    False  False  False  False     False    False  False
# 11625   False  False    False  False  False  False     False    False  False
# 11626   False  False     True  False  False  False     False    False  False
#
#        DIABETES  ...    CVD  HYPERTEN  TIMEAP  TIMEMI  TIMEMIFC  TIMECHD  \
# 0         False  ...  False     False   False   False     False    False
# 1         False  ...  False     False   False   False     False    False
# 2         False  ...  False     False   False   False     False    False
# 3         False  ...  False     False   False   False     False    False
# 4         False  ...  False     False   False   False     False    False
# ...         ...  ...    ...       ...     ...     ...       ...      ...
# 11622     False  ...  False     False   False   False     False    False
# 11623     False  ...  False     False   False   False     False    False
# 11624     False  ...  False     False   False   False     False    False
# 11625     False  ...  False     False   False   False     False    False
# 11626     False  ...  False     False   False   False     False    False
#
#        TIMESTRK  TIMECVD  TIMEDTH  TIMEHYP
# 0         False    False    False    False
# 1         False    False    False    False
# 2         False    False    False    False
# 3         False    False    False    False
# 4         False    False    False    False
# ...         ...      ...      ...      ...
# 11622     False    False    False    False
# 11623     False    False    False    False
# 11624     False    False    False    False
# 11625     False    False    False    False
# 11626     False    False    False    False
#
# [11627 rows x 39 columns]

# %%
# Summarize the total missings per column
print(frame.isna().sum())
# Out:
# RANDID         0
# SEX            0
# TOTCHOL      409
# AGE            0
# SYSBP          0
# DIABP          0
# CURSMOKE       0
# CIGPDAY       79
# BMI           52
# DIABETES       0
# BPMEDS       593
# HEARTRTE       6
# GLUCOSE     1440
# educ         295
# PREVCHD        0
# PREVAP         0
# PREVMI         0
# PREVSTRK       0
# PREVHYP        0
# TIME           0
# PERIOD         0
# HDLC        8600
# LDLC        8601
# DEATH          0
# ANGINA         0
# HOSPMI         0
# MI_FCHD        0
# ANYCHD         0
# STROKE         0
# CVD            0
# HYPERTEN       0
# TIMEAP         0
# TIMEMI         0
# TIMEMIFC       0
# TIMECHD        0
# TIMESTRK       0
# TIMECVD        0
# TIMEDTH        0
# TIMEHYP        0
# dtype: int64

# %%
frame[['HDLC','LDLC','TOTCHOL']]
# Out:
#        HDLC   LDLC  TOTCHOL
# 0       NaN    NaN    195.0
# 1      31.0  178.0    209.0
# 2       NaN    NaN    250.0
# 3       NaN    NaN    260.0
# 4      54.0  141.0    237.0
# ...     ...    ...      ...
# 11622   NaN    NaN    173.0
# 11623  30.0  123.0    153.0
# 11624   NaN    NaN    196.0
# 11625   NaN    NaN    240.0
# 11626   NaN    NaN      NaN
#
# [11627 rows x 3 columns]

# %%
# How many people have at least one missing data point?
frame['missing_per_row'] = frame.isna().sum(axis=1)

# %%
frame.head()
# Out:
#    RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 0    2448    1    195.0   39  106.0   70.0         0      0.0  26.97
# 1    2448    1    209.0   52  121.0   66.0         0      0.0    NaN
# 2    6238    2    250.0   46  121.0   81.0         0      0.0  28.73
# 3    6238    2    260.0   52  105.0   69.5         0      0.0  29.43
# 4    6238    2    237.0   58  108.0   66.0         0      0.0  28.50
#
#    DIABETES  ...  HYPERTEN  TIMEAP  TIMEMI  TIMEMIFC  TIMECHD  TIMESTRK  \
# 0         0  ...         0    8766    6438      6438     6438      8766
# 1         0  ...         0    8766    6438      6438     6438      8766
# 2         0  ...         0    8766    8766      8766     8766      8766
# 3         0  ...         0    8766    8766      8766     8766      8766
# 4         0  ...         0    8766    8766      8766     8766      8766
#
#    TIMECVD  TIMEDTH  TIMEHYP  missing_per_row
# 0     6438     8766     8766                2
# 1     6438     8766     8766                1
# 2     8766     8766     8766                2
# 3     8766     8766     8766                2
# 4     8766     8766     8766                0
#
# [5 rows x 40 columns]

# %%
frame[['RANDID','missing_per_row']].groupby('RANDID').sum().sort_values('missing_per_row')
# Out:
#          missing_per_row
# RANDID
# 2838795                2
# 9433633                2
# 9431604                2
# 2650858                2
# 8330956                2
# ...                  ...
# 2449215               12
# 4162270               12
# 6603907               12
# 6750830               12
# 2605055               14
#
# [4434 rows x 1 columns]

# %% [markdown]
# # Dealing with missings: dropping rows/columns

# %%
# Drop rows with ANY missing value:
frame.dropna()
# Out:
#         RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 4         6238    2    237.0   58  108.0   66.0         0      0.0  28.50
# 14       11263    2    220.0   55  180.0  106.0         0      0.0  31.17
# 19       12806    2    320.0   57  110.0   46.0         1     30.0  22.02
# 22       14367    1    280.0   64  168.0  100.0         0      0.0  25.72
# 25       16365    1    211.0   55  173.0  123.0         0      0.0  29.11
# ...        ...  ...      ...  ...    ...    ...       ...      ...    ...
# 11603  9978986    2    243.0   68  110.0   66.0         0      0.0  24.30
# 11606  9982118    1    219.0   70  163.5   75.0         0      0.0  25.26
# 11615  9990894    2    228.0   60  205.0  100.0         1     20.0  22.37
# 11618  9993179    2    251.0   56  145.0   92.0         1     35.0  21.97
# 11623  9998212    1    153.0   52  143.0   89.0         0      0.0  25.74
#
#        DIABETES  ...  HYPERTEN  TIMEAP  TIMEMI  TIMEMIFC  TIMECHD  TIMESTRK  \
# 4             0  ...         0    8766    8766      8766     8766      8766
# 14            1  ...         1    8766    8766      5719     5719      8766
# 19            0  ...         1    8766    8766      8766     8766      8766
# 22            0  ...         1    8766    8766      8766     8766      8766
# 25            0  ...         1    8766    8766      8766     8766      8766
# ...         ...  ...       ...     ...     ...       ...      ...       ...
# 11603         0  ...         1    8766    8766      8766     8766      8766
# 11606         0  ...         1    8457    8457      8457     8457      8346
# 11615         0  ...         1    6433    6433      6433     6433      6433
# 11618         0  ...         1    6729    6729      6729     6729      6729
# 11623         0  ...         1    8766    8766      8766     8766      8766
#
#        TIMECVD  TIMEDTH  TIMEHYP  missing_per_row
# 4         8766     8766     8766                0
# 14        5719     8766        0                0
# 19        8766     8766     8679                0
# 22        8766     8766        0                0
# 25        8766     8766        0                0
# ...        ...      ...      ...              ...
# 11603     8766     8766        0                0
# 11606     8346     8457        0                0
# 11615     6433     6433     2219                0
# 11618     6729     6729     4396                0
# 11623     8766     8766        0                0
#
# [2236 rows x 40 columns]

# %%
# Drop rows ONLY if ALL the values are missing
frame.dropna(how = 'all')
# Out:
#         RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 0         2448    1    195.0   39  106.0   70.0         0      0.0  26.97
# 1         2448    1    209.0   52  121.0   66.0         0      0.0    NaN
# 2         6238    2    250.0   46  121.0   81.0         0      0.0  28.73
# 3         6238    2    260.0   52  105.0   69.5         0      0.0  29.43
# 4         6238    2    237.0   58  108.0   66.0         0      0.0  28.50
# ...        ...  ...      ...  ...    ...    ...       ...      ...    ...
# 11622  9998212    1    173.0   46  126.0   82.0         0      0.0  19.17
# 11623  9998212    1    153.0   52  143.0   89.0         0      0.0  25.74
# 11624  9999312    2    196.0   39  133.0   86.0         1     30.0  20.91
# 11625  9999312    2    240.0   46  138.0   79.0         1     20.0  26.39
# 11626  9999312    2      NaN   50  147.0   96.0         1     10.0  24.19
#
#        DIABETES  ...  HYPERTEN  TIMEAP  TIMEMI  TIMEMIFC  TIMECHD  TIMESTRK  \
# 0             0  ...         0    8766    6438      6438     6438      8766
# 1             0  ...         0    8766    6438      6438     6438      8766
# 2             0  ...         0    8766    8766      8766     8766      8766
# 3             0  ...         0    8766    8766      8766     8766      8766
# 4             0  ...         0    8766    8766      8766     8766      8766
# ...         ...  ...       ...     ...     ...       ...      ...       ...
# 11622         0  ...         1    8766    8766      8766     8766      8766
# 11623         0  ...         1    8766    8766      8766     8766      8766
# 11624         0  ...         1    8766    8766      8766     8766      8766
# 11625         0  ...         1    8766    8766      8766     8766      8766
# 11626         0  ...         1    8766    8766      8766     8766      8766
#
#        TIMECVD  TIMEDTH  TIMEHYP  missing_per_row
# 0         6438     8766     8766                2
# 1         6438     8766     8766                1
# 2         8766     8766     8766                2
# 3         8766     8766     8766                2
# 4         8766     8766     8766                0
# ...        ...      ...      ...              ...
# 11622     8766     8766        0                3
# 11623     8766     8766        0                0
# 11624     8766     8766     4201                2
# 11625     8766     8766     4201                2
# 11626     8766     8766     4201                4
#
# [11627 rows x 40 columns]

# %%
# Drop columns with ANY missing value
frame.dropna(axis=1)
# Out:
#         RANDID  SEX  AGE  SYSBP  DIABP  CURSMOKE  DIABETES  PREVCHD  PREVAP  \
# 0         2448    1   39  106.0   70.0         0         0        0       0
# 1         2448    1   52  121.0   66.0         0         0        0       0
# 2         6238    2   46  121.0   81.0         0         0        0       0
# 3         6238    2   52  105.0   69.5         0         0        0       0
# 4         6238    2   58  108.0   66.0         0         0        0       0
# ...        ...  ...  ...    ...    ...       ...       ...      ...     ...
# 11622  9998212    1   46  126.0   82.0         0         0        0       0
# 11623  9998212    1   52  143.0   89.0         0         0        0       0
# 11624  9999312    2   39  133.0   86.0         1         0        0       0
# 11625  9999312    2   46  138.0   79.0         1         0        0       0
# 11626  9999312    2   50  147.0   96.0         1         0        0       0
#
#        PREVMI  ...  HYPERTEN  TIMEAP  TIMEMI  TIMEMIFC  TIMECHD  TIMESTRK  \
# 0           0  ...         0    8766    6438      6438     6438      8766
# 1           0  ...         0    8766    6438      6438     6438      8766
# 2           0  ...         0    8766    8766      8766     8766      8766
# 3           0  ...         0    8766    8766      8766     8766      8766
# 4           0  ...         0    8766    8766      8766     8766      8766
# ...       ...  ...       ...     ...     ...       ...      ...       ...
# 11622       0  ...         1    8766    8766      8766     8766      8766
# 11623       0  ...         1    8766    8766      8766     8766      8766
# 11624       0  ...         1    8766    8766      8766     8766      8766
# 11625       0  ...         1    8766    8766      8766     8766      8766
# 11626       0  ...         1    8766    8766      8766     8766      8766
#
#        TIMECVD  TIMEDTH  TIMEHYP  missing_per_row
# 0         6438     8766     8766                2
# 1         6438     8766     8766                1
# 2         8766     8766     8766                2
# 3         8766     8766     8766                2
# 4         8766     8766     8766                0
# ...        ...      ...      ...              ...
# 11622     8766     8766        0                3
# 11623     8766     8766        0                0
# 11624     8766     8766     4201                2
# 11625     8766     8766     4201                2
# 11626     8766     8766     4201                4
#
# [11627 rows x 31 columns]

# %% [markdown]
# # Dealing with missings: filling missing data

# %%
# Fill with a value:
frame['TOTCHOL'] = frame['TOTCHOL'].fillna(99)

# %%
frame.head(15)
# Out:
#     RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 0     2448    1    195.0   39  106.0   70.0         0      0.0  26.97
# 1     2448    1    209.0   52  121.0   66.0         0      0.0    NaN
# 2     6238    2    250.0   46  121.0   81.0         0      0.0  28.73
# 3     6238    2    260.0   52  105.0   69.5         0      0.0  29.43
# 4     6238    2    237.0   58  108.0   66.0         0      0.0  28.50
# 5     9428    1    245.0   48  127.5   80.0         1     20.0  25.34
# 6     9428    1    283.0   54  141.0   89.0         1     30.0  25.34
# 7    10552    2    225.0   61  150.0   95.0         1     30.0  28.58
# 8    10552    2    232.0   67  183.0  109.0         1     20.0  30.18
# 9    11252    2    285.0   46  130.0   84.0         1     23.0  23.10
# 10   11252    2    343.0   51  109.0   77.0         1     30.0  23.48
# 11   11252    2     99.0   58  155.0   90.0         1     30.0  24.61
# 12   11263    2    228.0   43  180.0  110.0         0      0.0  30.30
# 13   11263    2    230.0   49  177.0  102.0         0      0.0  31.36
# 14   11263    2    220.0   55  180.0  106.0         0      0.0  31.17
#
#     DIABETES  ...  HYPERTEN  TIMEAP  TIMEMI  TIMEMIFC  TIMECHD  TIMESTRK  \
# 0          0  ...         0    8766    6438      6438     6438      8766
# 1          0  ...         0    8766    6438      6438     6438      8766
# 2          0  ...         0    8766    8766      8766     8766      8766
# 3          0  ...         0    8766    8766      8766     8766      8766
# 4          0  ...         0    8766    8766      8766     8766      8766
# 5          0  ...         0    8766    8766      8766     8766      8766
# 6          0  ...         0    8766    8766      8766     8766      8766
# 7          0  ...         1    2956    2956      2956     2956      2089
# 8          0  ...         1    2956    2956      2956     2956      2089
# 9          0  ...         1    8766    8766      8766     8766      8766
# 10         0  ...         1    8766    8766      8766     8766      8766
# 11         0  ...         1    8766    8766      8766     8766      8766
# 12         0  ...         1    8766    8766      5719     5719      8766
# 13         0  ...         1    8766    8766      5719     5719      8766
# 14         1  ...         1    8766    8766      5719     5719      8766
#
#     TIMECVD  TIMEDTH  TIMEHYP  missing_per_row
# 0      6438     8766     8766                2
# 1      6438     8766     8766                1
# 2      8766     8766     8766                2
# 3      8766     8766     8766                2
# 4      8766     8766     8766                0
# 5      8766     8766     8766                2
# 6      8766     8766     8766                2
# 7      2089     2956        0                2
# 8      2089     2956        0                2
# 9      8766     8766     4285                2
# 10     8766     8766     4285                2
# 11     8766     8766     4285                4
# 12     5719     8766        0                2
# 13     5719     8766        0                2
# 14     5719     8766        0                0
#
# [15 rows x 40 columns]

# %%
# Fill with mean of the variable
frame['BMI'] = frame['BMI'].fillna( frame['BMI'].mean() )

# %%
frame.head()
# Out:
#    RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY        BMI  \
# 0    2448    1    195.0   39  106.0   70.0         0      0.0  26.970000
# 1    2448    1    209.0   52  121.0   66.0         0      0.0  25.877349
# 2    6238    2    250.0   46  121.0   81.0         0      0.0  28.730000
# 3    6238    2    260.0   52  105.0   69.5         0      0.0  29.430000
# 4    6238    2    237.0   58  108.0   66.0         0      0.0  28.500000
#
#    DIABETES  ...  HYPERTEN  TIMEAP  TIMEMI  TIMEMIFC  TIMECHD  TIMESTRK  \
# 0         0  ...         0    8766    6438      6438     6438      8766
# 1         0  ...         0    8766    6438      6438     6438      8766
# 2         0  ...         0    8766    8766      8766     8766      8766
# 3         0  ...         0    8766    8766      8766     8766      8766
# 4         0  ...         0    8766    8766      8766     8766      8766
#
#    TIMECVD  TIMEDTH  TIMEHYP  missing_per_row
# 0     6438     8766     8766                2
# 1     6438     8766     8766                1
# 2     8766     8766     8766                2
# 3     8766     8766     8766                2
# 4     8766     8766     8766                0
#
# [5 rows x 40 columns]

# %% [markdown]
# # Detecting duplicates

# %%
frame.duplicated().sum()
# Out:
# np.int64(0)

# %%
# If you have any duplicates:
frame = frame.drop_duplicates()

# %% [markdown]
# # Variable types revisited

# %%
frame.dtypes
# Out:
# RANDID               int64
# SEX                  int64
# TOTCHOL            float64
# AGE                  int64
# SYSBP              float64
# DIABP              float64
# CURSMOKE             int64
# CIGPDAY            float64
# BMI                float64
# DIABETES             int64
# BPMEDS             float64
# HEARTRTE           float64
# GLUCOSE            float64
# educ               float64
# PREVCHD              int64
# PREVAP               int64
# PREVMI               int64
# PREVSTRK             int64
# PREVHYP              int64
# TIME                 int64
# PERIOD               int64
# HDLC               float64
# LDLC               float64
# DEATH                int64
# ANGINA               int64
# HOSPMI               int64
# MI_FCHD              int64
# ANYCHD               int64
# STROKE               int64
# CVD                  int64
# HYPERTEN             int64
# TIMEAP               int64
# TIMEMI               int64
# TIMEMIFC             int64
# TIMECHD              int64
# TIMESTRK             int64
# TIMECVD              int64
# TIMEDTH              int64
# TIMEHYP              int64
# missing_per_row      int64
# dtype: object

# %%
frame['AGE'] = frame['AGE'].astype(float)

# %%
frame.dtypes
# Out:
# RANDID               int64
# SEX                  int64
# TOTCHOL            float64
# AGE                float64
# SYSBP              float64
# DIABP              float64
# CURSMOKE             int64
# CIGPDAY            float64
# BMI                float64
# DIABETES             int64
# BPMEDS             float64
# HEARTRTE           float64
# GLUCOSE            float64
# educ               float64
# PREVCHD              int64
# PREVAP               int64
# PREVMI               int64
# PREVSTRK             int64
# PREVHYP              int64
# TIME                 int64
# PERIOD               int64
# HDLC               float64
# LDLC               float64
# DEATH                int64
# ANGINA               int64
# HOSPMI               int64
# MI_FCHD              int64
# ANYCHD               int64
# STROKE               int64
# CVD                  int64
# HYPERTEN             int64
# TIMEAP               int64
# TIMEMI               int64
# TIMEMIFC             int64
# TIMECHD              int64
# TIMESTRK             int64
# TIMECVD              int64
# TIMEDTH              int64
# TIMEHYP              int64
# missing_per_row      int64
# dtype: object

# %% [markdown]
# # Storing your cleaned dataframe

# %%
# Let's load the Framingham Heart Study dataset
filename = 'drive/MyDrive/Colab Notebooks/Intro to Python for Epidemiologists/Data/frmgham2_cleaned.csv'
frame.to_csv(filename)
