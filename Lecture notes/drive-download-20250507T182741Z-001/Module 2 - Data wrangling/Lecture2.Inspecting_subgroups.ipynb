# %% [markdown]
# # Learning goals
# - Filter a dataset to access a specific subgroup of data
# - Use different methods for slicing a Pandas DataFrame
# - Apply functions to a subgroup or slice of a DataFrame

# %%
import numpy as np
import pandas as pd
import os

# %%
# Make Google Drive available to the script
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Let's load the Framingham Heart Study dataset
filename = 'drive/MyDrive/Colab Notebooks/Intro to Python for Epidemiologists/Data/frmgham2.csv'
frame = pd.read_csv(filename)
frame.head()
# Out:
#    RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 0    2448    1    195.0   39  106.0   70.0         0      0.0  26.97
# 1    2448    1    209.0   52  121.0   66.0         0      0.0    NaN
# 2    6238    2    250.0   46  121.0   81.0         0      0.0  28.73
# 3    6238    2    260.0   52  105.0   69.5         0      0.0  29.43
# 4    6238    2    237.0   58  108.0   66.0         0      0.0  28.50
#
#    DIABETES  ...  CVD  HYPERTEN  TIMEAP  TIMEMI  TIMEMIFC  TIMECHD  TIMESTRK  \
# 0         0  ...    1         0    8766    6438      6438     6438      8766
# 1         0  ...    1         0    8766    6438      6438     6438      8766
# 2         0  ...    0         0    8766    8766      8766     8766      8766
# 3         0  ...    0         0    8766    8766      8766     8766      8766
# 4         0  ...    0         0    8766    8766      8766     8766      8766
#
#    TIMECVD  TIMEDTH  TIMEHYP
# 0     6438     8766     8766
# 1     6438     8766     8766
# 2     8766     8766     8766
# 3     8766     8766     8766
# 4     8766     8766     8766
#
# [5 rows x 39 columns]

# %% [markdown]
# # Demographics (continued)

# %%
pd.DataFrame(frame['AGE'].value_counts()).sort_values('AGE')
# Out:
#      count
# AGE
# 32       1
# 33       5
# 34      18
# 35      42
# 36      84
# 37      93
# 38     145
# 39     178
# 40     212
# 41     213
# 42     258
# 43     256
# 44     304
# 45     339
# 46     380
# 47     342
# 48     426
# 49     367
# 50     426
# 51     448
# 52     470
# 53     433
# 54     464
# 55     399
# 56     396
# 57     386
# 58     404
# 59     367
# 60     382
# 61     348
# 62     341
# 63     357
# 64     321
# 65     290
# 66     237
# 67     266
# 68     216
# 69     192
# 70     169
# 71     142
# 72     110
# 73     107
# 74      90
# 75      71
# 76      51
# 77      33
# 78      18
# 79      21
# 80       6
# 81       3

# %%
# Create groupings of age
frame['age_group'] = pd.cut(frame['AGE'], bins = [25, 35, 45, 55, 65, 75, 85])
frame.head()
# Out:
#    RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 0    2448    1    195.0   39  106.0   70.0         0      0.0  26.97
# 1    2448    1    209.0   52  121.0   66.0         0      0.0    NaN
# 2    6238    2    250.0   46  121.0   81.0         0      0.0  28.73
# 3    6238    2    260.0   52  105.0   69.5         0      0.0  29.43
# 4    6238    2    237.0   58  108.0   66.0         0      0.0  28.50
#
#    DIABETES  ...  HYPERTEN  TIMEAP  TIMEMI  TIMEMIFC  TIMECHD  TIMESTRK  \
# 0         0  ...         0    8766    6438      6438     6438      8766
# 1         0  ...         0    8766    6438      6438     6438      8766
# 2         0  ...         0    8766    8766      8766     8766      8766
# 3         0  ...         0    8766    8766      8766     8766      8766
# 4         0  ...         0    8766    8766      8766     8766      8766
#
#    TIMECVD  TIMEDTH  TIMEHYP  age_group
# 0     6438     8766     8766   (35, 45]
# 1     6438     8766     8766   (45, 55]
# 2     8766     8766     8766   (45, 55]
# 3     8766     8766     8766   (45, 55]
# 4     8766     8766     8766   (55, 65]
#
# [5 rows x 40 columns]

# %%
pd.DataFrame(frame['age_group'].value_counts()).sort_values('age_group')
# Out:
#            count
# age_group
# (25, 35]      66
# (35, 45]    2082
# (45, 55]    4155
# (55, 65]    3592
# (65, 75]    1600
# (75, 85]     132

# %%
frame['educ'].value_counts()
# Out:
# educ
# 1.0    4690
# 2.0    3410
# 3.0    1885
# 4.0    1347
# Name: count, dtype: int64

# %% [markdown]
# # Outcomes

# %%
frame['PREVCHD'].value_counts()
# Out:
# PREVCHD
# 0    10785
# 1      842
# Name: count, dtype: int64

# %%
pd.DataFrame(frame[['age_group','PREVCHD']].value_counts()).sort_values('PREVCHD', ascending = False)
# Out:
#                    count
# age_group PREVCHD
# (45, 55]  1          158
# (65, 75]  1          273
# (55, 65]  1          365
# (35, 45]  1           23
# (75, 85]  1           23
# (45, 55]  0         3997
# (55, 65]  0         3227
# (35, 45]  0         2059
# (65, 75]  0         1327
# (25, 35]  0           66
# (75, 85]  0          109

# %% [markdown]
# # Longitudinal observations per person

# %%
len(frame['RANDID'].unique())
# Out:
# 4434

# %%
# Observations versus nr of participants
print('This dataset has %i rows (observations) and %i unique individuals.'%(
    frame.shape[0], len(frame['RANDID'].unique()))
)
# Out:
# This dataset has 11627 rows (observations) and 4434 unique individuals.

# %% [markdown]
# # Slicing and indexing dataframes

# %%
frame.loc[1:5, ['SEX','AGE']]
# Out:
#    SEX  AGE
# 1    1   52
# 2    2   46
# 3    2   52
# 4    2   58
# 5    1   48

# %%
# Extract rows 6 through 10 for columns AGE and TOTCHOL
frame.loc[6:10, ['AGE','TOTCHOL']]
# Out:
#     AGE  TOTCHOL
# 6    54    283.0
# 7    61    225.0
# 8    67    232.0
# 9    46    285.0
# 10   51    343.0

# %%
frame.iloc[6:10,1:4]
# Out:
#    SEX  TOTCHOL  AGE
# 6    1    283.0   54
# 7    2    225.0   61
# 8    2    232.0   67
# 9    2    285.0   46

# %% [markdown]
# ### Slicing with booleans

# %%
# How can we get ONLY the data for participants of 80 years old?
frame.loc[frame['AGE']==80, :]
# Out:
#         RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 3144   2693641    1    175.0   80  106.0   56.0         1      2.0  18.29
# 7333   6343336    2    179.0   80  159.0   65.0         0      0.0  20.78
# 7489   6494685    2    213.0   80  120.0   49.0         0      0.0  21.80
# 10070  8723664    2    215.0   80  188.0   88.0         0      0.0  19.01
# 10554  9093148    1    217.0   80  162.0   74.0         0      0.0  31.78
# 10683  9199095    1    264.0   80  140.0   90.0         0      0.0  27.93
#
#        DIABETES  ...  HYPERTEN  TIMEAP  TIMEMI  TIMEMIFC  TIMECHD  TIMESTRK  \
# 3144          0  ...         0    4470    4470      4470     4470      4470
# 7333          0  ...         1    8016    8016      8016     8016      8016
# 7489          0  ...         1    1784    5589      5589     1784      5589
# 10070         1  ...         1    7359    7359      7359     7359      7359
# 10554         0  ...         1    5206    5206      5206     5206      5206
# 10683         0  ...         0    6568    6568      6568     6568      6568
#
#        TIMECVD  TIMEDTH  TIMEHYP  age_group
# 3144      4470     4470     4470   (75, 85]
# 7333      8016     8016      735   (75, 85]
# 7489      5589     5589        0   (75, 85]
# 10070     7359     7359        0   (75, 85]
# 10554     5206     5206      719   (75, 85]
# 10683     6568     6568     6568   (75, 85]
#
# [6 rows x 40 columns]

# %%
person_of_interest = 8723664
person_data = frame.loc[frame['RANDID']==person_of_interest, :]
person_data.head()
# Out:
#         RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 10068  8723664    2    203.0   69  166.0   90.0         0      0.0  25.40
# 10069  8723664    2    224.0   75  195.0   98.0         0      0.0  22.51
# 10070  8723664    2    215.0   80  188.0   88.0         0      0.0  19.01
#
#        DIABETES  ...  HYPERTEN  TIMEAP  TIMEMI  TIMEMIFC  TIMECHD  TIMESTRK  \
# 10068         0  ...         1    7359    7359      7359     7359      7359
# 10069         0  ...         1    7359    7359      7359     7359      7359
# 10070         1  ...         1    7359    7359      7359     7359      7359
#
#        TIMECVD  TIMEDTH  TIMEHYP  age_group
# 10068     7359     7359        0   (65, 75]
# 10069     7359     7359        0   (65, 75]
# 10070     7359     7359        0   (75, 85]
#
# [3 rows x 40 columns]
