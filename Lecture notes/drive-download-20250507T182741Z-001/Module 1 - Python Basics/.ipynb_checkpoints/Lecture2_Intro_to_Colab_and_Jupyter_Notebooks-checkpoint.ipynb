# %% [markdown]
# After computing the sum of 3 and 4, we're now going to divid 8 by 2

# %%
8/2
# Out:
# 4.0

# %% [markdown]
# # This is my title
# Here is some text

# %%
3+4
# Out:
# 7

# %% [markdown]
# # Working with variables

# %% [markdown]
# ## THis is a subsection

# %%
myvariable = 3.2
